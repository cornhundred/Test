# %%
from clustergrammer_widget import *

# %%
net = Network(clustergrammer_widget)

# %%
net.load_file('/Users/MikeAllevato/Desktop/BioinformaticsUCSD/RNA-Seq/CD8andCD4fromTumorandBlood/11_1_18_Mike_Allevato_SmartseqQXT-100783378/Normalized_Hits/4M1TumorCD8vs4M3TumorCD8NormalizedHitsPerSample.tsv')

# %%
net.cluster()

# %%
net.widget()
# Out:
# clustergrammer_widget(network='{"row_nodes": [{"name": "Igfbp7", "ini": 38, "clust": 0, "rank": 37, "rankvar":…
