# %%
import numpy as np
import pandas as pd
from clustergrammer_widget import *

# %%
df= pd.read_table('/Users/mallevato/Desktop/BioinformaticsUCSD/2018-11-03 4M1 and 4M3- CD8 and CD4/11_1_18_Mike_Allevato_SmartseqQXT-100783378/CD4_Tumor_4M3_vs_4M1-135505827/control_vs_comparison-ds.ca85a65a6fd6410dab9d36c42a381ee6/CD4-4M3Tumorvs4M1TumorNormalizedHitsPerSample.tsv', index_col=0)

# %%
net = Network(clustergrammer_widget)

# %%
net.load_df(df)

# %%
net.cluster(enrichrgram=True)

# %%
net.widget()
# Out:
# clustergrammer_widget(network='{"row_nodes": [{"name": "Rgs2", "ini": 69, "clust": 1, "rank": 5, "rankvar": 42…
